# %% [markdown]
# # 00. Data Ingestion & Pipeline Orchestration
# **Objective:** Automate the acquisition of base geometries and massive historical parking events, provide guidance for manual portal datasets, and execute the end-to-end ETL spatial matching pipeline to populate the DuckDB database.

# %% [markdown]
# ### 1. Environment Setup & Dependency Installation
# Ensure that all required dependencies (GeoPandas, DuckDB, Pandas, PyYAML, etc.) are installed in your active Jupyter environment.

# %%
import sys
import os
from pathlib import Path

# Path to the .venv in the project root
venv_path = Path("../../../../.venv")

if not venv_path.exists():
    print("Virtual environment not found. Creating and installing dependencies...")
    # !python3 -m venv ../../../.venv
    # !../../../.venv/bin/pip install -r ../../../requirements.txt

# Dynamically load venv dependencies into the notebook session
site_packages_dirs = list(venv_path.glob("lib/python*/site-packages"))
if site_packages_dirs:
    site_packages = str(site_packages_dirs[0].resolve())
    if site_packages not in sys.path:
        sys.path.insert(0, site_packages)
        print(f"Dynamically loaded venv dependencies from {site_packages}")
# Out:
# Virtual environment not found. Creating and installing dependencies...
# Looking in indexes: https://us-python.pkg.dev/artifact-foundry-prod/ah-3p-staging-python/simple/
# Requirement already satisfied: pandas>=2.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 3)) (3.0.5)
# Requirement already satisfied: numpy>=1.24.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 4)) (2.5.1)
# Requirement already satisfied: scipy>=1.10.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 5)) (1.18.0)
# Requirement already satisfied: statsmodels>=0.14.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 6)) (0.14.6)
# Requirement already satisfied: matplotlib>=3.7.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 9)) (3.11.1)
# Requirement already satisfied: plotly>=5.14.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 10)) (6.9.0)
# Requirement already satisfied: seaborn>=0.12.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 11)) (0.13.2)
# Requirement already satisfied: geopandas>=0.13.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 14)) (1.1.4)
# Requirement already satisfied: shapely>=2.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 15)) (2.1.2)
# Requirement already satisfied: fiona>=1.9.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 16)) (1.10.1)
# Requirement already satisfied: pyproj>=3.5.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 17)) (3.7.2)
# Requirement already satisfied: jupyterlab>=4.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 20)) (4.6.2)
# Requirement already satisfied: fastapi>=0.100.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 23)) (0.140.0)
# Requirement already satisfied: uvicorn>=0.22.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 24)) (0.51.0)
# Requirement already satisfied: duckdb>=0.8.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 25)) (1.5.5)
# Requirement already satisfied: requests>=2.31.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 26)) (2.34.2)
# Requirement already satisfied: pyyaml>=6.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from -r ../../../requirements.txt (line 27)) (6.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from pandas>=2.0.0->-r ../../../requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: patsy>=0.5.6 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from statsmodels>=0.14.0->-r ../../../requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from statsmodels>=0.14.0->-r ../../../requirements.txt (line 6)) (26.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r ../../../requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r ../../../requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r ../../../requirements.txt (line 9)) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r ../../../requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: pillow>=9 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r ../../../requirements.txt (line 9)) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from matplotlib>=3.7.0->-r ../../../requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: narwhals>=1.15.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from plotly>=5.14.0->-r ../../../requirements.txt (line 10)) (2.24.0)
# Requirement already satisfied: pyogrio>=0.7.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from geopandas>=0.13.0->-r ../../../requirements.txt (line 14)) (0.13.0)
# Requirement already satisfied: attrs>=19.2.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fiona>=1.9.0->-r ../../../requirements.txt (line 16)) (26.1.0)
# Requirement already satisfied: certifi in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fiona>=1.9.0->-r ../../../requirements.txt (line 16)) (2026.7.22)
# Requirement already satisfied: click~=8.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fiona>=1.9.0->-r ../../../requirements.txt (line 16)) (8.4.2)
# Requirement already satisfied: click-plugins>=1.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fiona>=1.9.0->-r ../../../requirements.txt (line 16)) (1.1.1.2)
# Requirement already satisfied: cligj>=0.5 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fiona>=1.9.0->-r ../../../requirements.txt (line 16)) (0.7.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.3.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (7.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.1.6)
# Requirement already satisfied: jupyter-builder>=1.0.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.1.1)
# Requirement already satisfied: jupyter-core in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.19.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.2.4)
# Requirement already satisfied: tornado>=6.2.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (6.5.7)
# Requirement already satisfied: traitlets in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (5.15.1)
# Requirement already satisfied: anyio in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (4.14.2)
# Requirement already satisfied: httpcore==1.* in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.0.9)
# Requirement already satisfied: idna in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from httpx<1,>=0.25.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.18)
# Requirement already satisfied: h11>=0.16 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (8.9.1)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.26.0)
# Requirement already satisfied: pyzmq>=24 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (27.1.0)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (4.26.0)
# Requirement already satisfied: starlette>=0.46.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (1.3.1)
# Requirement already satisfied: pydantic>=2.9.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (2.13.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (4.16.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (0.4.2)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (0.0.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from requests>=2.31.0->-r ../../../requirements.txt (line 26)) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from requests>=2.31.0->-r ../../../requirements.txt (line 26)) (2.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (25.1.0)
# Requirement already satisfied: appnope>=0.1.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.8.21)
# Requirement already satisfied: ipython>=7.23.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (9.15.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.2.2)
# Requirement already satisfied: nest-asyncio2>=1.7.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.7.2)
# Requirement already satisfied: psutil>=5.7 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (7.2.2)
# Requirement already satisfied: decorator>=5.1.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.20.0)
# Requirement already satisfied: pexpect>4.6 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.0.53)
# Requirement already satisfied: pygments>=2.14.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.6.3)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jedi>=0.18.2->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jinja2>=3.0.3->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2026.6.3)
# Requirement already satisfied: platformdirs>=2.5 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-core->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (4.11.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (25.10.0)
# Requirement already satisfied: beautifulsoup4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (4.15.0)
# Requirement already satisfied: bleach!=5.0.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (6.4.0)
# Requirement already satisfied: defusedxml in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.22.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from pexpect>4.6->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.7.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from pydantic>=2.9.0->fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from pydantic>=2.9.0->fastapi>=0.100.0->-r ../../../requirements.txt (line 23)) (2.46.4)
# Requirement already satisfied: six>=1.5 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->-r ../../../requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.0.2)
# Requirement already satisfied: pure-eval in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.1.0)
# Requirement already satisfied: pycparser in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (3.0)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2.9.1)
# Requirement already satisfied: arrow>=0.15.0 in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (1.4.0)
# Requirement already satisfied: tzdata in /Users/szanevra/repositories/Victoria-Urban-Planning/.venv/lib/python3.13/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.19.0->jupyterlab>=4.0.0->-r ../../../requirements.txt (line 20)) (2026.3)

# %% [markdown]
# ### 2. Download Base GeoJSON Datasets
# Automates the retrieval of Bicycle Networks, Parking Bays, and Suburb polygons using paths defined in `config.yaml`.

# %%
import urllib.request
import yaml
from pathlib import Path

# Load project configuration
config_path = Path("../../../config.yaml")
with open(config_path, "r") as f:
    config = yaml.safe_load(f)

raw_dir = Path("../../../") / config["paths"]["raw_dir"]
raw_dir.mkdir(parents=True, exist_ok=True)

def download_url(url, dest_name):
    dest_path = raw_dir / dest_name
    if dest_path.exists():
        print(f"{dest_name} already exists. Skipping.")
        return
    print(f"Downloading {dest_name}...")
    urllib.request.urlretrieve(url, dest_path)
    print(f"Saved to {dest_path}")

download_url(config["data_sources"]["bicycle_network"], "bicycle_network.geojson")
download_url(config["data_sources"]["parking_bays"], "on_street_parking_bays.geojson")
download_url(config["data_sources"]["suburbs"], "suburbs.geojson")
# Out:
# bicycle_network.geojson already exists. Skipping.
# on_street_parking_bays.geojson already exists. Skipping.
# suburbs.geojson already exists. Skipping.

# %% [markdown]
# ### 3. Programmatically Download Historical Parking Sensor CSVs
# Leverages the direct streaming export capabilities of the Melbourne Open Data API to fetch the 2013 and 2014 massive event logs directly into the extraction paths expected by the pipeline.

# %%
import zipfile
import urllib.request
from pathlib import Path

(raw_dir / "parking_2013_extracted").mkdir(exist_ok=True)
(raw_dir / "parking_2014_extracted").mkdir(exist_ok=True)

zip_urls = {
    "parking_2013_extracted": {
        "url": "https://opendatasoft-s3.s3.amazonaws.com/downloads/archive/7jq6-k9kf.zip",
        "csv_name": "On-street_Car_Parking_Sensor_Data_-_2013.csv"
    },
    "parking_2014_extracted": {
        "url": "https://opendatasoft-s3.s3.amazonaws.com/downloads/archive/t6hb-9uf2.zip",
        "csv_name": "On-street_Car_Parking_Sensor_Data_-_2014.csv"
    }
}

for folder, info in zip_urls.items():
    dest_dir = raw_dir / folder
    dest_csv = dest_dir / info["csv_name"]
    
    if dest_csv.exists():
        print(f"{dest_csv.name} already exists. Skipping.")
        continue
        
    zip_path = dest_dir / "dataset.zip"
    print(f"Downloading {folder} from OpenDataSoft S3 (this is a massive file, 1.2-1.5 GB and will take a few minutes)...")
    urllib.request.urlretrieve(info["url"], zip_path)
    print(f"Downloaded. Extracting...")
    
    with zipfile.ZipFile(zip_path, 'r') as zip_ref:
        # Find the CSV file in the zip
        csv_files = [f for f in zip_ref.namelist() if f.endswith('.csv')]
        if csv_files:
            extracted_path = zip_ref.extract(csv_files[0], dest_dir)
            Path(extracted_path).rename(dest_csv)
            print(f"Extracted and renamed to {dest_csv.name}")
        else:
            print(f"No CSV file found in zip!")
            
    # Clean up the zip file to save space
    zip_path.unlink()
    print(f"Saved to {dest_csv}")
# Out:
# parking_2013_extracted/On-street_Car_Parking_Sensor_Data_-_2013.csv already exists. Skipping.
# parking_2014_extracted/On-street_Car_Parking_Sensor_Data_-_2014.csv already exists. Skipping.

# %% [markdown]
# ### 4. Manual Download Instructions for SCATS and VISTA Data
# Due to authentication or specific access constraints on the Victorian Government portals, the SCATS Volume and VISTA Survey datasets must be downloaded manually:
#
# 1. **SCATS Traffic Volume Data**:
#    - Visit the [DataVic Portal](https://discover.data.vic.gov.au/dataset/scats-traffic-signal-volume-data) (or search for SCATS Traffic Signal Volume Data).
#    - Export/Download the historical volume CSV files.
#    - Place the main volume CSV file exactly at: `data/raw/scats_volume_data.csv`
#
# 2. **VISTA Travel Survey Data**:
#    - Visit the [Transport Victoria Open Data Portal](https://opendata.transport.vic.gov.au/) and register/login.
#    - Search for VISTA (Victorian Integrated Survey of Travel and Activity).
#    - Download the recent historical survey data CSV.
#    - Place it exactly at: `data/raw/vista_travel_survey.csv`
#
# > **Note:** Because raw SCATS and VISTA schemas vary depending on portal export options, once you place the CSV files, you may need to update the column names in **Notebook 2** and **Notebook 4** to match your exact export headers.

# %% [markdown]
# ### 5. Execute the End-to-End ETL Pipeline
# Once the base GeoJSONs and Parking CSVs are downloaded, and you have placed the SCATS and VISTA files in `data/raw/`, run the cell below to build the complete spatial mappings and the DuckDB analytical database!

# %%
# !../../.venv/bin/python ../../run_ingestion.py
# Out:
# ============================================================
#       Victoria Urban Planning - Full Ingestion Pipeline
# ============================================================
# This script will process all raw data, perform spatial joins, and
# build the complete DuckDB database for all supported streets.
# Processing historical sensor events (40M+ rows per year) will
# take a few minutes. Please be patient.
#
# ============================================================
# [*] Running download_base_data.py ...
# ============================================================
# Bicycle Network already exists at /Users/szanevra/repositories/Victoria-Urban-Planning/data/raw/bicycle_network.geojson. Skipping download.
# Parking Bays already exists at /Users/szanevra/repositories/Victoria-Urban-Planning/data/raw/on_street_parking_bays.geojson. Skipping download.
# Suburbs already exists at /Users/szanevra/repositories/Victoria-Urban-Planning/data/raw/suburbs.geojson. Skipping download.
#
# [+] download_base_data.py completed successfully in 2.03 seconds.
#
# ============================================================
# [*] Running match_bike_lanes.py ...
# ============================================================
# Loading data...
# Loaded 130048 bike segments, 29053 bays, 13 suburbs.
# Filtered to 9728 valid bicycle infrastructure line segments.
# Bays after dropping intersections: 28542
# Spatial join bays with suburbs...
# Bays after suburb join: 28506
# Projecting to EPSG:7899...
# Buffering parking bays by 20 meters...
# Performing spatial join between bike segments and buffered bays...
# Found 123 supported street-suburb combinations with >= 10 bays.
# Mapping primary suburb and street to bike segments...
# Final matched bike segments: 6144
# Final bays on supported streets: 12738
# Projecting back to WGS84...
# Saved matched layers to /Users/szanevra/repositories/Victoria-Urban-Planning/data/processed
#
# [+] match_bike_lanes.py completed successfully in 2.74 seconds.
#
# ============================================================
# [*] Running filter_supported_events.py 2013...
# ============================================================
# Filtering On-street_Car_Parking_Sensor_Data_-_2013.csv for supported streets using DuckDB...
# Loading matched bays and building street filter...
# Matching against 96 distinct normalized streets.
# Error executing DuckDB query: Binder Error: Referenced column "ArrivalTime" not found in FROM clause!
# Candidate bindings: "record_timestamp", "_record_timestamp", "record_size", "_record_size", "recordid"
#
# LINE 14:             WHERE ArrivalTime IS NOT NULL
#                            ^
#
# [+] filter_supported_events.py completed successfully in 0.52 seconds.
#
# ============================================================
# [*] Running filter_supported_events.py 2014...
# ============================================================
# Filtering On-street_Car_Parking_Sensor_Data_-_2014.csv for supported streets using DuckDB...
# Loading matched bays and building street filter...
# Matching against 96 distinct normalized streets.
# Error executing DuckDB query: Binder Error: Referenced column "ArrivalTime" not found in FROM clause!
# Candidate bindings: "record_timestamp", "_record_timestamp", "record_size", "_record_size", "recordid"
#
# LINE 14:             WHERE ArrivalTime IS NOT NULL
#                            ^
#
# [+] filter_supported_events.py completed successfully in 0.47 seconds.
#
# ============================================================
# [*] Running aggregate_occupancy.py ...
# ============================================================
# Loading matched bays to build block mapping...
# Built mapping for 457 unique blocks across all supported streets.
# Parquet not found for 2013: /Users/szanevra/repositories/Victoria-Urban-Planning/data/processed/matched_events_2013.parquet
# Parquet not found for 2014: /Users/szanevra/repositories/Victoria-Urban-Planning/data/processed/matched_events_2014.parquet
# Aggregation Summary (Year, Rows, Distinct Streets):
# Database saved to /Users/szanevra/repositories/Victoria-Urban-Planning/data/parking_analytics.duckdb
#
# [+] aggregate_occupancy.py completed successfully in 0.49 seconds.
#
# ============================================================
# [*] Running match_bike_to_blocks.py ...
# ============================================================
# Loading data...
# Projecting to EPSG:7899...
# Buffering bike segments by 20 meters...
# Performing spatial join to map blocks to bike segments...
# Mapping primary suburb, street, and block to bike segments...
# Mapped 6144 bike segments to blocks.
# Dissolving geometries by block...
# Saving geometries to DuckDB...
# Building blocks_summary table...
# Blocks summary table created!
#
# Summary of streets with actual historical data support:
# Empty DataFrame
# Columns: [suburb, streets_with_data, total_blocks]
# Index: []
#
# [+] match_bike_to_blocks.py completed successfully in 1.79 seconds.
#
# ============================================================
#  SUCCESS: Ingestion Pipeline Completed Successfully!
#  Total Execution Time: 0m 8s
#  The DuckDB database is now fully populated and ready for the app.
#  Run 'python run_app.py' to start the dashboard.
# ============================================================
